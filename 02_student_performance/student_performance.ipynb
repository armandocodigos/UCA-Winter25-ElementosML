# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
student_performance = fetch_ucirepo(id=320) 
# data (as pandas dataframes) 
X = student_performance.data.features 
y = student_performance.data.targets

# %%
X.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   higher internet  romantic  famrel  freetime goout Dalc Walc health absences
# 0    yes       no        no       4         3     4    1    1      3        4
# 1    yes      yes        no       5         3     3    1    1      3        2
# 2    yes      yes        no       4         3     2    2    3      3        6
# 3    yes      yes       yes       3         2     2    1    1      5        0
# 4    yes       no        no       4         3     2    1    2      5        0
#
# [5 rows x 30 columns]

# %%
X["school"].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
X["school"].value_counts()
# Out:
# school
# GP    423
# MS    226
# Name: count, dtype: int64

# %%
X["school"].isna().sum()
# Out:
# np.int64(0)

# %%
X = pd.get_dummies(X, columns=["school"], drop_first=True, dtype=int)
#X_prime.head()
X.head()
# Out:
#   sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason  \
# 0   F   18       U     GT3       A     4     4  at_home   teacher  course
# 1   F   17       U     GT3       T     1     1  at_home     other  course
# 2   F   15       U     LE3       T     1     1  at_home     other   other
# 3   F   15       U     GT3       T     4     2   health  services    home
# 4   F   16       U     GT3       T     3     3    other     other    home
#
#    ... internet  romantic  famrel  freetime goout Dalc Walc health absences  \
# 0  ...       no        no       4         3     4    1    1      3        4
# 1  ...      yes        no       5         3     3    1    1      3        2
# 2  ...      yes        no       4         3     2    2    3      3        6
# 3  ...      yes       yes       3         2     2    1    1      5        0
# 4  ...       no        no       4         3     2    1    2      5        0
#
#   school_MS
# 0         0
# 1         0
# 2         0
# ...

# %%
X = pd.get_dummies(X, columns=["sex"], drop_first=True, dtype=int)
X.head()
# Out:
#    age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason  \
# 0   18       U     GT3       A     4     4  at_home   teacher  course
# 1   17       U     GT3       T     1     1  at_home     other  course
# 2   15       U     LE3       T     1     1  at_home     other   other
# 3   15       U     GT3       T     4     2   health  services    home
# 4   16       U     GT3       T     3     3    other     other    home
#
#   guardian  ...  romantic  famrel  freetime goout Dalc Walc health absences  \
# 0   mother  ...        no       4         3     4    1    1      3        4
# 1   father  ...        no       5         3     3    1    1      3        2
# 2   mother  ...        no       4         3     2    2    3      3        6
# 3   mother  ...       yes       3         2     2    1    1      5        0
# 4   father  ...        no       4         3     2    1    2      5        0
#
#   school_MS sex_M
# 0         0     0
# 1         0     0
# 2         0     0
# ...

# %%
X = pd.get_dummies(X, columns=["address", "famsize", "Pstatus"], drop_first=True, dtype=int)
X.head()
# Out:
#    age  Medu  Fedu     Mjob      Fjob  reason guardian  traveltime  studytime  \
# 0   18     4     4  at_home   teacher  course   mother           2          2
# 1   17     1     1  at_home     other  course   father           1          2
# 2   15     1     1  at_home     other   other   mother           1          2
# 3   15     4     2   health  services    home   mother           1          3
# 4   16     3     3    other     other    home   father           1          2
#
#    failures  ... goout Dalc Walc health absences school_MS sex_M address_U  \
# 0         0  ...     4    1    1      3        4         0     0         1
# 1         0  ...     3    1    1      3        2         0     0         1
# 2         0  ...     2    2    3      3        6         0     0         1
# 3         0  ...     2    1    1      5        0         0     0         1
# 4         0  ...     2    1    2      5        0         0     0         1
#
#    famsize_LE3  Pstatus_T
# ...

# %%
X["Mjob"].unique()
# Out:
# array(['at_home', 'health', 'other', 'services', 'teacher'], dtype=object)

# %%
X_prime = pd.get_dummies(X, columns=["Mjob"], drop_first=True, dtype=int)
X_prime.head()
# Out:
#    age  Medu  Fedu      Fjob  reason guardian  traveltime  studytime  \
# 0   18     4     4   teacher  course   mother           2          2
# 1   17     1     1     other  course   father           1          2
# 2   15     1     1     other   other   mother           1          2
# 3   15     4     2  services    home   mother           1          3
# 4   16     3     3     other    home   father           1          2
#
#    failures schoolsup  ... absences school_MS sex_M address_U famsize_LE3  \
# 0         0       yes  ...        4         0     0         1           0
# 1         0        no  ...        2         0     0         1           0
# 2         0       yes  ...        6         0     0         1           1
# 3         0        no  ...        0         0     0         1           0
# 4         0        no  ...        0         0     0         1           0
#
#   Pstatus_T Mjob_health  Mjob_other  Mjob_services  Mjob_teacher
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()

# %%
X.loc[:, "Mjob"] = encoder.fit_transform(X[["Mjob"]])
X.head()
# Out:
#    age  Medu  Fedu Mjob      Fjob  reason guardian  traveltime  studytime  \
# 0   18     4     4  0.0   teacher  course   mother           2          2
# 1   17     1     1  0.0     other  course   father           1          2
# 2   15     1     1  0.0     other   other   mother           1          2
# 3   15     4     2  1.0  services    home   mother           1          3
# 4   16     3     3  2.0     other    home   father           1          2
#
#    failures  ... goout Dalc Walc health absences school_MS sex_M address_U  \
# 0         0  ...     4    1    1      3        4         0     0         1
# 1         0  ...     3    1    1      3        2         0     0         1
# 2         0  ...     2    2    3      3        6         0     0         1
# 3         0  ...     2    1    1      5        0         0     0         1
# 4         0  ...     2    1    2      5        0         0     0         1
#
#    famsize_LE3  Pstatus_T
# 0            0          0
# ...

# %%
X.loc[:, "Fjob"] = encoder.fit_transform(X[["Fjob"]])
X.loc[:, "reason"] = encoder.fit_transform(X[["reason"]])
X.loc[:, "guardian"] = encoder.fit_transform(X[["guardian"]])
X.head()
# Out:
#    age  Medu  Fedu Mjob Fjob reason guardian  traveltime  studytime  failures  \
# 0   18     4     4  0.0  4.0    0.0      1.0           2          2         0
# 1   17     1     1  0.0  2.0    0.0      0.0           1          2         0
# 2   15     1     1  0.0  2.0    2.0      1.0           1          2         0
# 3   15     4     2  1.0  3.0    1.0      1.0           1          3         0
# 4   16     3     3  2.0  2.0    1.0      0.0           1          2         0
#
#    ... goout Dalc Walc health absences school_MS sex_M address_U  famsize_LE3  \
# 0  ...     4    1    1      3        4         0     0         1            0
# 1  ...     3    1    1      3        2         0     0         1            0
# 2  ...     2    2    3      3        6         0     0         1            1
# 3  ...     2    1    1      5        0         0     0         1            0
# 4  ...     2    1    2      5        0         0     0         1            0
#
#    Pstatus_T
# 0          0
# ...

# %%
pd.options.display.max_columns = 0

# %%
X.head()
# Out:
#    age  Medu  Fedu Mjob  ... sex_M address_U famsize_LE3  Pstatus_T
# 0   18     4     4  0.0  ...     0         1           0          0
# 1   17     1     1  0.0  ...     0         1           0          1
# 2   15     1     1  0.0  ...     0         1           1          1
# 3   15     4     2  1.0  ...     0         1           0          1
# 4   16     3     3  2.0  ...     0         1           0          1
#
# [5 rows x 30 columns]

# %%
X = X.drop(columns=["schoolsup", "famsup", "paid", "activities", "nursery", "higher", "internet", "romantic"])
X.head()
# Out:
#    age  Medu  Fedu Mjob  ... sex_M address_U famsize_LE3  Pstatus_T
# 0   18     4     4  0.0  ...     0         1           0          0
# 1   17     1     1  0.0  ...     0         1           0          1
# 2   15     1     1  0.0  ...     0         1           1          1
# 3   15     4     2  1.0  ...     0         1           0          1
# 4   16     3     3  2.0  ...     0         1           0          1
#
# [5 rows x 22 columns]

# %%
y = y[["G1"]]
y.head()
# Out:
#    G1
# 0   0
# 1   9
# 2  12
# 3  14
# 4  11

# %%
from sklearn.model_selection import train_test_split
#train 80%
#resto: val_test 20%
#  validation 10%
#  test 10%

# %%
X_train, X_resto = train_test_split(X, test_size=0.2, random_state=42)
X_train.shape, X_resto.shape
# Out:
# ((519, 22), (130, 22))

# %%
X_val, X_test = train_test_split(X_resto, test_size=0.5, random_state=42)
X_val.shape, X_test.shape
# Out:
# ((65, 22), (65, 22))

# %%
y_train, y_resto = train_test_split(y, test_size=0.2, random_state=42)
y_val, y_test = train_test_split(y_resto, test_size=0.5, random_state=42)

y_train = np.reshape(y_train, -1)
y_val = np.reshape(y_val, -1)
y_test = np.reshape(y_test, -1)

y_train.shape, y_val.shape, y_test.shape
# Out:
# ((519,), (65,), (65,))

# %%
from sklearn.svm import SVR
from sklearn.svm import LinearSVR

# %%
grados = [1, 2, 3, 4, 5, 6, 8, 10]
epsilons = [0.1, 0.25, 0.5, 1, 1.5]
penalidades = [0.1, 1, 5, 10, 25, 50, 100]

resultados = []
for g in grados:
    for e in epsilons:
        for c in penalidades:
            print("Modelo: G={}, E={}, C={}".format(g, e, c), end=' ')
            if(g == 1):
                modelo = LinearSVR(C=c, epsilon=e, max_iter=1000)
            else:
                modelo = SVR(kernel="poly", degree=g, epsilon=e, max_iter=1000)
            modelo.fit(X_train, y_train)
            
            y_pred = modelo.predict(X_val)
            
            rmse = np.sqrt(np.mean(np.square(y_val - y_pred)))
            
            rango = y_train.max() - y_train.min()
            nrmse = (rmse / rango) * 100
            print("Validation NRMSE: {}%".format(round(nrmse, 4)))
            
            resultados.append({"model":modelo, "Val NRMSE":nrmse})
# Out:
# Modelo: G=1, E=0.1, C=0.1 Validation NRMSE: 14.1651%
# Modelo: G=1, E=0.1, C=1 Validation NRMSE: 14.2747%
# Modelo: G=1, E=0.1, C=5 Validation NRMSE: 15.6452%
# Modelo: G=1, E=0.1, C=10 Validation NRMSE: 15.3278%
# Modelo: G=1, E=0.1, C=25 Validation NRMSE: 14.463%
# Modelo: G=1, E=0.1, C=50 Validation NRMSE: 18.3968%
# Modelo: G=1, E=0.1, C=100
# C:\Users\ronal\anaconda3\envs\UCA_ML\lib\site-packages\sklearn\svm\_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\ronal\anaconda3\envs\UCA_ML\lib\site-packages\sklearn\svm\_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\ronal\anaconda3\envs\UCA_ML\lib\site-packages\sklearn\svm\_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
df_resultados = pd.DataFrame(resultados)
df_resultados.head()
# Out:
#                            model  Val NRMSE
# 0  LinearSVR(C=0.1, epsilon=0.1)  14.165105
# 1    LinearSVR(C=1, epsilon=0.1)  14.274690
# 2    LinearSVR(C=5, epsilon=0.1)  15.645164
# 3   LinearSVR(C=10, epsilon=0.1)  15.327827
# 4   LinearSVR(C=25, epsilon=0.1)  14.462959

# %%
df_resultados.describe()
# Out:
#         Val NRMSE
# count  280.000000
# mean    26.922285
# std     36.247761
# min     13.833311
# 25%     15.098061
# 50%     15.988205
# 75%     20.138210
# max    226.723482

# %%
top5 = df_resultados.nsmallest(5, "Val NRMSE")
top5
# Out:
#                              model  Val NRMSE
# 8     LinearSVR(C=1, epsilon=0.25)  13.833311
# 17    LinearSVR(C=10, epsilon=0.5)  14.147657
# 0    LinearSVR(C=0.1, epsilon=0.1)  14.165105
# 7   LinearSVR(C=0.1, epsilon=0.25)  14.198701
# 15     LinearSVR(C=1, epsilon=0.5)  14.229141

# %%
for t in top5.values.tolist():
    modelo = t[0]
    y_pred = modelo.predict(X_test)
    
    rmse = np.sqrt(np.mean(np.square(y_test - y_pred)))
    
    #rango = y_train.max() - y_train.min()
    nrmse = (rmse / rango) * 100
    print("Test NRMSE: {}%".format(round(nrmse, 4)))
# Out:
# Test NRMSE: 14.5721%
# Test NRMSE: 14.2301%
# Test NRMSE: 14.6085%
# Test NRMSE: 14.6961%
# Test NRMSE: 14.6548%

# %%
import pickle
filename = 'finalized_model.sav'
pickle.dump(top5.values.tolist()[1][0], open(filename, 'wb'))
